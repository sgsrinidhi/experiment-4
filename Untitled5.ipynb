# %% [markdown]
# <a href="https://colab.research.google.com/github/sgsrinidhi/experiment-4/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Class Definitions based on your Class Diagram

class Bank:
    def __init__(self, name, location, password):
        self.name = name
        self.location = location
        self.password = password
        self.branches = []

    def addBranch(self, branch):
        self.branches.append(branch)

    def removeBranch(self, branch):
        self.branches.remove(branch)

    def getBranch(self):
        return self.branches

    def getAllBranches(self):
        return [branch.city for branch in self.branches]


class Branch:
    def __init__(self, city, postal_code, state):
        self.city = city
        self.postal_code = postal_code
        self.state = state
        self.accounts = []

    def addAccount(self, account):
        self.accounts.append(account)

    def removeAccount(self, account):
        self.accounts.remove(account)


class Account:
    def __init__(self, acc_no, balance):
        self.acc_no = acc_no
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient funds!")

    def addLoan(self, loan):
        pass  # Logic for adding a loan

    def removeLoan(self, loan):
        pass  # Logic for removing a loan


class Loan:
    def __init__(self, loan_no, amount, type_):
        self.loan_no = loan_no
        self.amount = amount
        self.type = type_

    def addCustomer(self, customer):
        pass  # Logic for adding customer

    def removeCustomer(self, customer):
        pass  # Logic for removing customer

    def getEMI(self):
        pass  # Logic for calculating EMI


class SavingAccount(Account):
    def __init__(self, acc_no, balance, min_balance, int_rate, opening_date):
        super().__init__(acc_no, balance)
        self.min_balance = min_balance
        self.int_rate = int_rate
        self.opening_date = opening_date

    def addCustomer(self, customer):
        pass  # Logic for adding customer

    def removeCustomer(self, customer):
        pass  # Logic for removing customer


class Customer:
    def __init__(self, name, address, email):
        self.name = name
        self.address = address
        self.email = email
